# %% [markdown]
# <a href="https://colab.research.google.com/github/Leanse1/Amazon-Go-Prototype/blob/main/Custom_Grocery_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import Image, display

# %%
# !git clone https://github.com/ultralytics/ultralytics.git
# Out:
# fatal: destination path 'ultralytics' already exists and is not an empty directory.

# %%
# %cd /content/ultralytics
# Out:
# /content/ultralytics

# %%
# !pip install -e .'[dev]'

# %%
# %cd /content/ultralytics/ultralytics/models/yolo/detect
# Out:
# /content/ultralytics/ultralytics/models/yolo/detect

# %%
# !pwd

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="vSLqNlAbwI46rXUil85o")
project = rf.workspace("fruits-dataset").project("fruitsv2-duplk")
dataset = project.version(5).download("yolov8")

# %%
dataset.location
# Out:
# '/content/ultralytics/ultralytics/models/yolo/detect/Fruitsv2-5'

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.yaml')  # build a new model from YAML
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)
model = YOLO('yolov8n.yaml').load('yolov8n.pt')  # build from YAML and transfer weights

# Train the model after making changes in data.yaml file like ../train/images
results = model.train(data='/content/ultralytics/ultralytics/models/yolo/detect/Fruitsv2-5/data.yaml', epochs=25, imgsz=640)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
import locale
print(locale.getpreferredencoding())
# Out:
# ANSI_X3.4-1968

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# !ls /content/ultralytics/runs/detect/train6
# Out:
# args.yaml					    R_curve.png		 val_batch0_labels.jpg
# confusion_matrix_normalized.png			    results.csv		 val_batch0_pred.jpg
# confusion_matrix.png				    results.png		 val_batch1_labels.jpg
# events.out.tfevents.1703084633.32b907a5c13c.1121.1  train_batch0.jpg	 val_batch1_pred.jpg
# F1_curve.png					    train_batch1215.jpg  val_batch2_labels.jpg
# labels_correlogram.jpg				    train_batch1216.jpg  val_batch2_pred.jpg
# labels.jpg					    train_batch1217.jpg  weights
# P_curve.png					    train_batch1.jpg
# PR_curve.png					    train_batch2.jpg

# %%
metrics = model.val()
metrics.box.map
metrics.box.map50
metrics.box.map75
metrics.box.maps
# Out:
# Ultralytics YOLOv8.0.228 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3006428 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/ultralytics/ultralytics/models/yolo/detect/Fruitsv2-5/valid/labels.cache... 160 images, 0 backgrounds, 0 corrupt: 100%|██████████| 160/160 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:04<00:00,  2.04it/s]
#                    all        160        226      0.974      0.969      0.988      0.868
#                  Apple        160         54      0.968      0.981       0.99      0.917
#                 Banana        160         54      0.996      0.963      0.993      0.898
#                 Carrot        160         60      0.949      0.939      0.973       0.71
#                 Orange        160         58      0.983      0.991      0.994      0.947
# ...

# %%
Image("/content/ultralytics/runs/detect/train6/val_batch0_pred.jpg")

# %%
Image("/content/ultralytics/runs/detect/train6/confusion_matrix_normalized.png")
