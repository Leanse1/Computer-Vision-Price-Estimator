# %% [markdown]
# <a href="https://colab.research.google.com/github/Leanse1/Amazon-Go-Prototype/blob/main/Amazon_Go_Prototype.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !git clone https://github.com/Leanse1/YOLOv8-DeepSORT-Object-Tracking.git
# Out:
# Cloning into 'YOLOv8-DeepSORT-Object-Tracking'...
# remote: Enumerating objects: 403, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 403 (delta 21), reused 19 (delta 19), pack-reused 370
# Receiving objects: 100% (403/403), 77.99 MiB | 30.26 MiB/s, done.
# Resolving deltas: 100% (206/206), done.

# %%
# %cd /content/YOLOv8-DeepSORT-Object-Tracking
# Out:
# /content/YOLOv8-DeepSORT-Object-Tracking

# %%
# !pip install -e '.[dev]'
# Out:
#   Running setup.py develop for ultralytics
# ...

# %%
# %cd /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect
# Out:
# /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect

# %%
# !gdown "https://drive.google.com/uc?id=11ZSZcG-bcbueXZC3rN08CM0qqX3eiHxf&confirm=t"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=11ZSZcG-bcbueXZC3rN08CM0qqX3eiHxf&confirm=t
# To: /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/deep_sort_pytorch.zip
# 100% 43.1M/43.1M [00:00<00:00, 180MB/s]

# %%
# !unzip 'deep_sort_pytorch.zip'

# %% [markdown]
# Download Sample File

# %%
# !gdown "https://drive.google.com/uc?id=1fKlz5ZiOKgvmsCeaS7Xsc4-CVKL9-PnY&confirm=t"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1fKlz5ZiOKgvmsCeaS7Xsc4-CVKL9-PnY&confirm=t
# To: /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/test.mp4
# 100% 981k/981k [00:00<00:00, 116MB/s]

# %%
# !python predict.py model=yolov8n.pt source="test.mp4"
# Out:
# [2023-12-13 10:48:32,963][root.tracker][INFO] - Loading weights from deep_sort_pytorch/deep_sort/deep/checkpoint/ckpt.t7... Done!
# 2023-12-13 10:48:33.432639: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-13 10:48:33.432700: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-13 10:48:33.432738: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-13 10:48:34.977250: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.3 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# Display Demo Video

# %%
# !rm "/content/result_compressed.mp4"

# %%
from IPython.display import HTML
from base64 import b64encode
import os

# Input video path
save_path = '/content/YOLOv8-DeepSORT-Object-Tracking/runs/detect/train13/test.mp4'

# Compressed video path
compressed_path = "/content/result_compressed.mp4"

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

# Show video
mp4 = open(compressed_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video width=400 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>
